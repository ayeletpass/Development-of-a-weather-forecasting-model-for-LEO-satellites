# %%
import lstm
import os

directory = os.path.join("c:\\","path")
for root,dirs,files in os.walk(directory):
    for file in files:
       if file.endswith(".csv"):
           new_table_list.append(file.split(".")[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2ebed43e304f> in <module>
#       2 import os
#       3
# ----> 4 directory = os.path.join()
#       5 for root,dirs,files in os.walk(directory):
#       6     for file in files:
#
# TypeError: join() missing 1 required positional argument: 'path'

# %%
for filename in os.listdir("C:\Windows\System32\cmd.exe"):
    if filename.endswith('.csv'):
        new_table_list.append(filename[:-4])
# Out:
#   File "<ipython-input-23-a97aa39dbc24>", line 1
#     for filename in os.listdir("C:\Users\Ayelet Rapaport\Desktop\‏‏תיקיה חדשה\Project"):
#                               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
main("simulator.ver5.csv", [450, 42])
# Out:
# Train on 591 samples, validate on 1091 samples
# Epoch 1/450
#  - 0s - loss: 0.2927 - val_loss: 0.3465
# Epoch 2/450
#  - 0s - loss: 0.2721 - val_loss: 0.3265
# Epoch 3/450
#  - 0s - loss: 0.2587 - val_loss: 0.3111
# Epoch 4/450
#  - 0s - loss: 0.2483 - val_loss: 0.2986
# Epoch 5/450
#  - 0s - loss: 0.2411 - val_loss: 0.2881
# Epoch 6/450
#  - 0s - loss: 0.2351 - val_loss: 0.2788
# Epoch 7/450
#  - 0s - loss: 0.2297 - val_loss: 0.2704
# Epoch 8/450
#  - 0s - loss: 0.2247 - val_loss: 0.2626
# Epoch 9/450
#  - 0s - loss: 0.2201 - val_loss: 0.2553
# Epoch 10/450
#  - 0s - loss: 0.2158 - val_loss: 0.2487
# Epoch 11/450
#  - 0s - loss: 0.2116 - val_loss: 0.2426
# Epoch 12/450
#  - 0s - loss: 0.2077 - val_loss: 0.2369
# Epoch 13/450
#  - 0s - loss: 0.2038 - val_loss: 0.2314
# Epoch 14/450
#  - 0s - loss: 0.2001 - val_loss: 0.2262
# Epoch 15/450
#  - 0s - loss: 0.1964 - val_loss: 0.2211
# Epoch 16/450
#  - 0s - loss: 0.1927 - val_loss: 0.2160
# Epoch 17/450
# ...
