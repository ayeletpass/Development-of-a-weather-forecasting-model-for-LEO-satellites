# %%
from datetime import datetime
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

def load_dataset(path):
    # load dataset
    dataset = read_csv(path, header=0)
    values = dataset.values
    # ensure all data is float
    values = values.astype('float32')
    # normalize features
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(values)
    return scaled, scaler

def split_train_test(scaled):
    # split into train and test sets
    n = scaled.shape[0]
    train = scaled[:591, :]
    test = scaled[591:1682, :]
    # split into input and outputs
    train_X, train_y = train[:, :-2], train[:, -2:]
    test_X, test_y = test[:, :-2], test[:, -2:]
    # reshape input to be 3D [samples, timesteps, features]
    train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
    test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
    return train_X, train_y, test_X, test_y

def lstm(train_X, train_y, test_X, test_y, params):
    epochs, batch_size = params
    model = Sequential()
    model.add(LSTM(train_X.shape[2], input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dense(2))
    model.compile(loss='mae', optimizer='adam')
    # fit network
    history = model.fit(train_X, train_y, epochs=epochs, batch_size=batch_size, validation_data=(test_X, test_y), verbose=2, shuffle=False)
    # make a prediction
    yhat = model.predict(test_X)
    return history, yhat

def calculate_rmse(y_predict, test, scaler):
    test_X, test_y = test
    test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

    # invert scaling for forecast
    inv_yhat = concatenate((y_predict, test_X[:, :]), axis=1)
    inv_yhat = scaler.inverse_transform(inv_yhat)
    inv_yhat = inv_yhat[:,0]
    # invert scaling for actual
    test_y = test_y.reshape((len(test_y), 2))
    inv_y = concatenate((test_y, test_X[:, :]), axis=1)

    inv_y = scaler.inverse_transform(inv_y)
    inv_y = inv_y[:,0]
    # calculate RMSE
    rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
    return round(rmse, 3)

def display_plot(title, x, y):
    # plot history
    pyplot.title(title)
    pyplot.plot(x[0], 'red', label=x[1])
    pyplot.plot(y[0], 'blue', label=y[1])
    pyplot.legend()
    pyplot.show()

def main(path, params):
    scaled, scaler = load_dataset(path)
    train_X, train_y, test_X, test_y = split_train_test(scaled)
    history, y_predict = lstm(train_X, train_y, test_X, test_y, params)
    rmse = calculate_rmse(y_predict, [test_X, test_y], scaler)
    print('rmse', rmse)
    # plot history
    display_plot("history", 
                 [history.history['loss'], 'train'],
                 [history.history['val_loss'], 'test'])
    # Graph 1
    display_plot("Prediction y1",
                 [y_predict[:, 0], 'y1 predict rain'],
                [test_y[:, 0], 'y1 test rain'])
    # Graph 2    
    display_plot("Prediction y2",
                 [y_predict[:, 1], 'y2 predict rain'],
                 [test_y[:, 1], 'y2 test rain']) 

if __name__ == "__main__":
    main("simulator.ver1.csv", [450, 42])
# Out:
# Using TensorFlow backend.
# C:\Users\Ayelet Rapaport\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Ayelet Rapaport\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Ayelet Rapaport\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Ayelet Rapaport\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Ayelet Rapaport\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Ayelet Rapaport\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Ayelet Rapaport\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Ayelet Rapaport\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Ayelet Rapaport\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Ayelet Rapaport\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Ayelet Rapaport\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Ayelet Rapaport\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From C:\Users\Ayelet Rapaport\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 591 samples, validate on 1090 samples
# Epoch 1/450
#  - 0s - loss: 0.2607 - val_loss: 0.3001
# Epoch 2/450
#  - 0s - loss: 0.2402 - val_loss: 0.2797
# Epoch 3/450
#  - 0s - loss: 0.2211 - val_loss: 0.2613
# Epoch 4/450
#  - 0s - loss: 0.2099 - val_loss: 0.2504
# Epoch 5/450
#  - 0s - loss: 0.2031 - val_loss: 0.2421
# Epoch 6/450
#  - 0s - loss: 0.1968 - val_loss: 0.2345
# Epoch 7/450
#  - 0s - loss: 0.1905 - val_loss: 0.2270
# Epoch 8/450
#  - 0s - loss: 0.1843 - val_loss: 0.2193
# Epoch 9/450
#  - 0s - loss: 0.1782 - val_loss: 0.2114
# Epoch 10/450
#  - 0s - loss: 0.1718 - val_loss: 0.2032
# Epoch 11/450
#  - 0s - loss: 0.1651 - val_loss: 0.1948
# Epoch 12/450
#  - 0s - loss: 0.1583 - val_loss: 0.1858
# Epoch 13/450
#  - 0s - loss: 0.1515 - val_loss: 0.1764
# Epoch 14/450
#  - 0s - loss: 0.1447 - val_loss: 0.1671
# Epoch 15/450
#  - 0s - loss: 0.1380 - val_loss: 0.1577
# Epoch 16/450
#  - 0s - loss: 0.1318 - val_loss: 0.1482
# Epoch 17/450
#  - 0s - loss: 0.1257 - val_loss: 0.1389
# Epoch 18/450
#  - 0s - loss: 0.1198 - val_loss: 0.1305
# Epoch 19/450
#  - 0s - loss: 0.1142 - val_loss: 0.1223
# Epoch 20/450
#  - 0s - loss: 0.1088 - val_loss: 0.1147
# Epoch 21/450
#  - 0s - loss: 0.1038 - val_loss: 0.1079
# Epoch 22/450
#  - 0s - loss: 0.0991 - val_loss: 0.1017
# Epoch 23/450
#  - 0s - loss: 0.0947 - val_loss: 0.0961
# Epoch 24/450
#  - 0s - loss: 0.0907 - val_loss: 0.0911
# Epoch 25/450
#  - 0s - loss: 0.0868 - val_loss: 0.0864
# Epoch 26/450
#  - 0s - loss: 0.0833 - val_loss: 0.0822
# Epoch 27/450
#  - 0s - loss: 0.0800 - val_loss: 0.0783
# Epoch 28/450
#  - 0s - loss: 0.0769 - val_loss: 0.0748
# Epoch 29/450
#  - 0s - loss: 0.0740 - val_loss: 0.0715
# Epoch 30/450
#  - 0s - loss: 0.0713 - val_loss: 0.0685
# Epoch 31/450
#  - 0s - loss: 0.0686 - val_loss: 0.0656
# Epoch 32/450
#  - 0s - loss: 0.0661 - val_loss: 0.0628
# Epoch 33/450
#  - 0s - loss: 0.0636 - val_loss: 0.0602
# Epoch 34/450
#  - 0s - loss: 0.0611 - val_loss: 0.0576
# Epoch 35/450
#  - 0s - loss: 0.0587 - val_loss: 0.0549
# Epoch 36/450
#  - 0s - loss: 0.0562 - val_loss: 0.0524
# Epoch 37/450
#  - 0s - loss: 0.0538 - val_loss: 0.0499
# Epoch 38/450
#  - 0s - loss: 0.0514 - val_loss: 0.0474
# Epoch 39/450
#  - 0s - loss: 0.0491 - val_loss: 0.0450
# Epoch 40/450
#  - 0s - loss: 0.0468 - val_loss: 0.0427
# Epoch 41/450
#  - 0s - loss: 0.0445 - val_loss: 0.0404
# Epoch 42/450
#  - 0s - loss: 0.0423 - val_loss: 0.0381
# Epoch 43/450
#  - 0s - loss: 0.0401 - val_loss: 0.0359
# Epoch 44/450
#  - 0s - loss: 0.0380 - val_loss: 0.0338
# Epoch 45/450
#  - 0s - loss: 0.0360 - val_loss: 0.0318
# Epoch 46/450
#  - 0s - loss: 0.0340 - val_loss: 0.0299
# Epoch 47/450
#  - 0s - loss: 0.0322 - val_loss: 0.0281
# Epoch 48/450
#  - 0s - loss: 0.0305 - val_loss: 0.0265
# Epoch 49/450
#  - 0s - loss: 0.0289 - val_loss: 0.0251
# Epoch 50/450
#  - 0s - loss: 0.0274 - val_loss: 0.0237
# Epoch 51/450
#  - 0s - loss: 0.0260 - val_loss: 0.0225
# Epoch 52/450
#  - 0s - loss: 0.0248 - val_loss: 0.0215
# Epoch 53/450
#  - 0s - loss: 0.0238 - val_loss: 0.0206
# Epoch 54/450
#  - 0s - loss: 0.0227 - val_loss: 0.0197
# Epoch 55/450
#  - 0s - loss: 0.0219 - val_loss: 0.0190
# Epoch 56/450
#  - 0s - loss: 0.0208 - val_loss: 0.0184
# Epoch 57/450
#  - 0s - loss: 0.0201 - val_loss: 0.0178
# Epoch 58/450
#  - 0s - loss: 0.0193 - val_loss: 0.0172
# Epoch 59/450
#  - 0s - loss: 0.0186 - val_loss: 0.0167
# Epoch 60/450
#  - 0s - loss: 0.0179 - val_loss: 0.0163
# Epoch 61/450
#  - 0s - loss: 0.0172 - val_loss: 0.0159
# Epoch 62/450
#  - 0s - loss: 0.0166 - val_loss: 0.0155
# Epoch 63/450
#  - 0s - loss: 0.0161 - val_loss: 0.0152
# Epoch 64/450
#  - 0s - loss: 0.0156 - val_loss: 0.0149
# Epoch 65/450
#  - 0s - loss: 0.0152 - val_loss: 0.0146
# Epoch 66/450
#  - 0s - loss: 0.0149 - val_loss: 0.0144
# Epoch 67/450
#  - 0s - loss: 0.0145 - val_loss: 0.0143
# Epoch 68/450
#  - 0s - loss: 0.0143 - val_loss: 0.0141
# Epoch 69/450
#  - 0s - loss: 0.0141 - val_loss: 0.0141
# Epoch 70/450
#  - 0s - loss: 0.0139 - val_loss: 0.0140
# Epoch 71/450
#  - 0s - loss: 0.0138 - val_loss: 0.0139
# Epoch 72/450
#  - 0s - loss: 0.0137 - val_loss: 0.0138
# Epoch 73/450
#  - 0s - loss: 0.0136 - val_loss: 0.0138
# Epoch 74/450
#  - 0s - loss: 0.0135 - val_loss: 0.0137
# Epoch 75/450
#  - 0s - loss: 0.0134 - val_loss: 0.0137
# Epoch 76/450
#  - 0s - loss: 0.0133 - val_loss: 0.0137
# Epoch 77/450
#  - 0s - loss: 0.0132 - val_loss: 0.0136
# Epoch 78/450
#  - 0s - loss: 0.0131 - val_loss: 0.0136
# Epoch 79/450
#  - 0s - loss: 0.0131 - val_loss: 0.0135
# Epoch 80/450
#  - 0s - loss: 0.0130 - val_loss: 0.0138
# Epoch 81/450
#  - 0s - loss: 0.0133 - val_loss: 0.0136
# Epoch 82/450
#  - 0s - loss: 0.0131 - val_loss: 0.0141
# Epoch 83/450
#  - 0s - loss: 0.0138 - val_loss: 0.0136
# Epoch 84/450
#  - 0s - loss: 0.0131 - val_loss: 0.0140
# Epoch 85/450
#  - 0s - loss: 0.0138 - val_loss: 0.0135
# Epoch 86/450
#  - 0s - loss: 0.0130 - val_loss: 0.0140
# Epoch 87/450
#  - 0s - loss: 0.0137 - val_loss: 0.0134
# Epoch 88/450
#  - 0s - loss: 0.0129 - val_loss: 0.0140
# Epoch 89/450
#  - 0s - loss: 0.0136 - val_loss: 0.0134
# Epoch 90/450
#  - 0s - loss: 0.0127 - val_loss: 0.0138
# Epoch 91/450
#  - 0s - loss: 0.0134 - val_loss: 0.0133
# Epoch 92/450
#  - 0s - loss: 0.0127 - val_loss: 0.0139
# Epoch 93/450
#  - 0s - loss: 0.0135 - val_loss: 0.0133
# Epoch 94/450
#  - 0s - loss: 0.0126 - val_loss: 0.0138
# Epoch 95/450
#  - 0s - loss: 0.0132 - val_loss: 0.0132
# Epoch 96/450
#  - 0s - loss: 0.0126 - val_loss: 0.0139
# Epoch 97/450
#  - 0s - loss: 0.0134 - val_loss: 0.0132
# Epoch 98/450
#  - 0s - loss: 0.0126 - val_loss: 0.0136
# Epoch 99/450
#  - 0s - loss: 0.0131 - val_loss: 0.0131
# Epoch 100/450
#  - 0s - loss: 0.0126 - val_loss: 0.0138
# Epoch 101/450
#  - 0s - loss: 0.0134 - val_loss: 0.0132
# Epoch 102/450
#  - 0s - loss: 0.0125 - val_loss: 0.0135
# Epoch 103/450
#  - 0s - loss: 0.0130 - val_loss: 0.0131
# Epoch 104/450
#  - 0s - loss: 0.0125 - val_loss: 0.0138
# Epoch 105/450
#  - 0s - loss: 0.0133 - val_loss: 0.0131
# Epoch 106/450
#  - 0s - loss: 0.0124 - val_loss: 0.0135
# Epoch 107/450
#  - 0s - loss: 0.0128 - val_loss: 0.0130
# Epoch 108/450
#  - 0s - loss: 0.0124 - val_loss: 0.0137
# Epoch 109/450
#  - 0s - loss: 0.0131 - val_loss: 0.0130
# Epoch 110/450
#  - 0s - loss: 0.0123 - val_loss: 0.0135
# Epoch 111/450
#  - 0s - loss: 0.0128 - val_loss: 0.0129
# Epoch 112/450
#  - 0s - loss: 0.0123 - val_loss: 0.0136
# Epoch 113/450
#  - 0s - loss: 0.0131 - val_loss: 0.0130
# Epoch 114/450
#  - 0s - loss: 0.0122 - val_loss: 0.0134
# Epoch 115/450
#  - 0s - loss: 0.0126 - val_loss: 0.0129
# Epoch 116/450
#  - 0s - loss: 0.0122 - val_loss: 0.0136
# Epoch 117/450
#  - 0s - loss: 0.0129 - val_loss: 0.0129
# Epoch 118/450
#  - 0s - loss: 0.0121 - val_loss: 0.0137
# Epoch 119/450
#  - 0s - loss: 0.0127 - val_loss: 0.0129
# Epoch 120/450
#  - 0s - loss: 0.0121 - val_loss: 0.0135
# Epoch 121/450
#  - 0s - loss: 0.0127 - val_loss: 0.0128
# Epoch 122/450
#  - 0s - loss: 0.0121 - val_loss: 0.0138
# Epoch 123/450
#  - 0s - loss: 0.0128 - val_loss: 0.0128
# Epoch 124/450
#  - 0s - loss: 0.0119 - val_loss: 0.0136
# Epoch 125/450
#  - 0s - loss: 0.0125 - val_loss: 0.0127
# Epoch 126/450
#  - 0s - loss: 0.0119 - val_loss: 0.0136
# Epoch 127/450
#  - 0s - loss: 0.0129 - val_loss: 0.0128
# Epoch 128/450
#  - 0s - loss: 0.0120 - val_loss: 0.0139
# Epoch 129/450
#  - 0s - loss: 0.0127 - val_loss: 0.0127
# Epoch 130/450
#  - 0s - loss: 0.0118 - val_loss: 0.0136
# Epoch 131/450
#  - 0s - loss: 0.0124 - val_loss: 0.0127
# Epoch 132/450
#  - 0s - loss: 0.0118 - val_loss: 0.0137
# Epoch 133/450
#  - 0s - loss: 0.0125 - val_loss: 0.0127
# Epoch 134/450
#  - 0s - loss: 0.0118 - val_loss: 0.0140
# Epoch 135/450
#  - 0s - loss: 0.0127 - val_loss: 0.0127
# Epoch 136/450
#  - 0s - loss: 0.0118 - val_loss: 0.0138
# Epoch 137/450
#  - 0s - loss: 0.0125 - val_loss: 0.0126
# Epoch 138/450
#  - 0s - loss: 0.0118 - val_loss: 0.0139
# Epoch 139/450
#  - 0s - loss: 0.0126 - val_loss: 0.0127
# Epoch 140/450
#  - 0s - loss: 0.0118 - val_loss: 0.0138
# Epoch 141/450
#  - 0s - loss: 0.0125 - val_loss: 0.0126
# Epoch 142/450
#  - 0s - loss: 0.0118 - val_loss: 0.0140
# Epoch 143/450
#  - 0s - loss: 0.0126 - val_loss: 0.0126
# Epoch 144/450
#  - 0s - loss: 0.0118 - val_loss: 0.0139
# Epoch 145/450
#  - 0s - loss: 0.0124 - val_loss: 0.0126
# Epoch 146/450
#  - 0s - loss: 0.0117 - val_loss: 0.0138
# Epoch 147/450
#  - 0s - loss: 0.0126 - val_loss: 0.0128
# Epoch 148/450
#  - 0s - loss: 0.0119 - val_loss: 0.0141
# Epoch 149/450
#  - 0s - loss: 0.0123 - val_loss: 0.0128
# Epoch 150/450
#  - 0s - loss: 0.0118 - val_loss: 0.0137
# Epoch 151/450
#  - 0s - loss: 0.0123 - val_loss: 0.0125
# Epoch 152/450
#  - 0s - loss: 0.0117 - val_loss: 0.0138
# Epoch 153/450
#  - 0s - loss: 0.0125 - val_loss: 0.0128
# Epoch 154/450
#  - 0s - loss: 0.0118 - val_loss: 0.0139
# Epoch 155/450
#  - 0s - loss: 0.0121 - val_loss: 0.0127
# Epoch 156/450
#  - 0s - loss: 0.0117 - val_loss: 0.0139
# Epoch 157/450
#  - 0s - loss: 0.0122 - val_loss: 0.0128
# Epoch 158/450
#  - 0s - loss: 0.0117 - val_loss: 0.0137
# Epoch 159/450
#  - 0s - loss: 0.0122 - val_loss: 0.0125
# Epoch 160/450
#  - 0s - loss: 0.0117 - val_loss: 0.0137
# Epoch 161/450
#  - 0s - loss: 0.0124 - val_loss: 0.0128
# Epoch 162/450
#  - 0s - loss: 0.0118 - val_loss: 0.0140
# Epoch 163/450
#  - 0s - loss: 0.0121 - val_loss: 0.0127
# Epoch 164/450
#  - 0s - loss: 0.0117 - val_loss: 0.0139
# Epoch 165/450
#  - 0s - loss: 0.0121 - val_loss: 0.0127
# Epoch 166/450
#  - 0s - loss: 0.0117 - val_loss: 0.0137
# Epoch 167/450
#  - 0s - loss: 0.0121 - val_loss: 0.0125
# Epoch 168/450
#  - 0s - loss: 0.0117 - val_loss: 0.0137
# Epoch 169/450
#  - 0s - loss: 0.0124 - val_loss: 0.0127
# Epoch 170/450
#  - 0s - loss: 0.0117 - val_loss: 0.0140
# Epoch 171/450
#  - 0s - loss: 0.0121 - val_loss: 0.0126
# Epoch 172/450
#  - 0s - loss: 0.0116 - val_loss: 0.0139
# Epoch 173/450
#  - 0s - loss: 0.0121 - val_loss: 0.0127
# Epoch 174/450
#  - 0s - loss: 0.0117 - val_loss: 0.0139
# Epoch 175/450
#  - 0s - loss: 0.0120 - val_loss: 0.0127
# Epoch 176/450
#  - 0s - loss: 0.0116 - val_loss: 0.0137
# Epoch 177/450
#  - 0s - loss: 0.0122 - val_loss: 0.0126
# Epoch 178/450
#  - 0s - loss: 0.0117 - val_loss: 0.0142
# Epoch 179/450
#  - 0s - loss: 0.0121 - val_loss: 0.0126
# Epoch 180/450
#  - 0s - loss: 0.0116 - val_loss: 0.0139
# Epoch 181/450
#  - 0s - loss: 0.0120 - val_loss: 0.0127
# Epoch 182/450
#  - 0s - loss: 0.0116 - val_loss: 0.0137
# Epoch 183/450
#  - 0s - loss: 0.0121 - val_loss: 0.0126
# Epoch 184/450
#  - 0s - loss: 0.0116 - val_loss: 0.0141
# Epoch 185/450
#  - 0s - loss: 0.0121 - val_loss: 0.0127
# Epoch 186/450
#  - 0s - loss: 0.0116 - val_loss: 0.0139
# Epoch 187/450
#  - 0s - loss: 0.0119 - val_loss: 0.0125
# Epoch 188/450
#  - 0s - loss: 0.0115 - val_loss: 0.0138
# Epoch 189/450
#  - 0s - loss: 0.0118 - val_loss: 0.0125
# Epoch 190/450
#  - 0s - loss: 0.0113 - val_loss: 0.0134
# Epoch 191/450
#  - 0s - loss: 0.0118 - val_loss: 0.0123
# Epoch 192/450
#  - 0s - loss: 0.0114 - val_loss: 0.0137
# Epoch 193/450
#  - 0s - loss: 0.0119 - val_loss: 0.0125
# Epoch 194/450
#  - 0s - loss: 0.0115 - val_loss: 0.0137
# Epoch 195/450
#  - 0s - loss: 0.0117 - val_loss: 0.0124
# Epoch 196/450
#  - 0s - loss: 0.0113 - val_loss: 0.0135
# Epoch 197/450
#  - 0s - loss: 0.0116 - val_loss: 0.0123
# Epoch 198/450
#  - 0s - loss: 0.0112 - val_loss: 0.0133
# Epoch 199/450
#  - 0s - loss: 0.0117 - val_loss: 0.0123
# Epoch 200/450
#  - 0s - loss: 0.0113 - val_loss: 0.0137
# Epoch 201/450
#  - 0s - loss: 0.0118 - val_loss: 0.0124
# Epoch 202/450
#  - 0s - loss: 0.0113 - val_loss: 0.0135
# Epoch 203/450
#  - 0s - loss: 0.0116 - val_loss: 0.0123
# Epoch 204/450
#  - 0s - loss: 0.0112 - val_loss: 0.0134
# Epoch 205/450
#  - 0s - loss: 0.0115 - val_loss: 0.0122
# Epoch 206/450
#  - 0s - loss: 0.0110 - val_loss: 0.0127
# Epoch 207/450
#  - 0s - loss: 0.0111 - val_loss: 0.0120
# Epoch 208/450
#  - 0s - loss: 0.0108 - val_loss: 0.0124
# Epoch 209/450
#  - 0s - loss: 0.0109 - val_loss: 0.0121
# Epoch 210/450
#  - 0s - loss: 0.0108 - val_loss: 0.0120
# Epoch 211/450
#  - 0s - loss: 0.0109 - val_loss: 0.0126
# Epoch 212/450
#  - 0s - loss: 0.0116 - val_loss: 0.0121
# Epoch 213/450
#  - 0s - loss: 0.0116 - val_loss: 0.0141
# Epoch 214/450
#  - 0s - loss: 0.0129 - val_loss: 0.0131
# Epoch 215/450
#  - 0s - loss: 0.0121 - val_loss: 0.0156
# Epoch 216/450
#  - 0s - loss: 0.0125 - val_loss: 0.0128
# Epoch 217/450
#  - 0s - loss: 0.0116 - val_loss: 0.0143
# Epoch 218/450
#  - 0s - loss: 0.0117 - val_loss: 0.0122
# Epoch 219/450
#  - 0s - loss: 0.0111 - val_loss: 0.0131
# Epoch 220/450
#  - 0s - loss: 0.0113 - val_loss: 0.0120
# Epoch 221/450
#  - 0s - loss: 0.0109 - val_loss: 0.0127
# Epoch 222/450
#  - 0s - loss: 0.0110 - val_loss: 0.0120
# Epoch 223/450
#  - 0s - loss: 0.0112 - val_loss: 0.0120
# Epoch 224/450
#  - 0s - loss: 0.0115 - val_loss: 0.0131
# Epoch 225/450
#  - 0s - loss: 0.0128 - val_loss: 0.0126
# Epoch 226/450
#  - 0s - loss: 0.0120 - val_loss: 0.0154
# Epoch 227/450
#  - 0s - loss: 0.0124 - val_loss: 0.0128
# Epoch 228/450
#  - 0s - loss: 0.0117 - val_loss: 0.0145
# Epoch 229/450
#  - 0s - loss: 0.0118 - val_loss: 0.0122
# Epoch 230/450
#  - 0s - loss: 0.0111 - val_loss: 0.0133
# Epoch 231/450
#  - 0s - loss: 0.0112 - val_loss: 0.0119
# Epoch 232/450
#  - 0s - loss: 0.0109 - val_loss: 0.0120
# Epoch 233/450
#  - 0s - loss: 0.0109 - val_loss: 0.0125
# Epoch 234/450
#  - 0s - loss: 0.0119 - val_loss: 0.0121
# Epoch 235/450
#  - 0s - loss: 0.0118 - val_loss: 0.0144
# Epoch 236/450
#  - 0s - loss: 0.0127 - val_loss: 0.0129
# Epoch 237/450
#  - 0s - loss: 0.0119 - val_loss: 0.0150
# Epoch 238/450
#  - 0s - loss: 0.0123 - val_loss: 0.0125
# Epoch 239/450
#  - 0s - loss: 0.0115 - val_loss: 0.0142
# Epoch 240/450
#  - 0s - loss: 0.0117 - val_loss: 0.0121
# Epoch 241/450
#  - 0s - loss: 0.0110 - val_loss: 0.0131
# Epoch 242/450
#  - 0s - loss: 0.0111 - val_loss: 0.0118
# Epoch 243/450
#  - 0s - loss: 0.0110 - val_loss: 0.0120
# Epoch 244/450
#  - 0s - loss: 0.0115 - val_loss: 0.0127
# Epoch 245/450
#  - 0s - loss: 0.0128 - val_loss: 0.0125
# Epoch 246/450
#  - 0s - loss: 0.0119 - val_loss: 0.0153
# Epoch 247/450
#  - 0s - loss: 0.0123 - val_loss: 0.0128
# Epoch 248/450
#  - 0s - loss: 0.0117 - val_loss: 0.0144
# Epoch 249/450
#  - 0s - loss: 0.0117 - val_loss: 0.0121
# Epoch 250/450
#  - 0s - loss: 0.0110 - val_loss: 0.0132
# Epoch 251/450
#  - 0s - loss: 0.0111 - val_loss: 0.0118
# Epoch 252/450
#  - 0s - loss: 0.0109 - val_loss: 0.0120
# Epoch 253/450
#  - 0s - loss: 0.0113 - val_loss: 0.0127
# Epoch 254/450
#  - 0s - loss: 0.0125 - val_loss: 0.0123
# Epoch 255/450
#  - 0s - loss: 0.0120 - val_loss: 0.0158
# Epoch 256/450
#  - 0s - loss: 0.0128 - val_loss: 0.0133
# Epoch 257/450
#  - 0s - loss: 0.0120 - val_loss: 0.0149
# Epoch 258/450
#  - 0s - loss: 0.0119 - val_loss: 0.0122
# Epoch 259/450
#  - 0s - loss: 0.0112 - val_loss: 0.0135
# Epoch 260/450
#  - 0s - loss: 0.0113 - val_loss: 0.0118
# Epoch 261/450
#  - 0s - loss: 0.0108 - val_loss: 0.0127
# Epoch 262/450
#  - 0s - loss: 0.0110 - val_loss: 0.0121
# Epoch 263/450
#  - 0s - loss: 0.0118 - val_loss: 0.0119
# Epoch 264/450
#  - 0s - loss: 0.0117 - val_loss: 0.0140
# Epoch 265/450
#  - 0s - loss: 0.0126 - val_loss: 0.0128
# Epoch 266/450
#  - 0s - loss: 0.0118 - val_loss: 0.0151
# Epoch 267/450
#  - 0s - loss: 0.0122 - val_loss: 0.0125
# Epoch 268/450
#  - 0s - loss: 0.0114 - val_loss: 0.0140
# Epoch 269/450
#  - 0s - loss: 0.0116 - val_loss: 0.0120
# Epoch 270/450
#  - 0s - loss: 0.0110 - val_loss: 0.0133
# Epoch 271/450
#  - 0s - loss: 0.0112 - val_loss: 0.0117
# Epoch 272/450
#  - 0s - loss: 0.0108 - val_loss: 0.0121
# Epoch 273/450
#  - 0s - loss: 0.0114 - val_loss: 0.0125
# Epoch 274/450
#  - 0s - loss: 0.0129 - val_loss: 0.0124
# Epoch 275/450
#  - 0s - loss: 0.0118 - val_loss: 0.0151
# Epoch 276/450
#  - 0s - loss: 0.0122 - val_loss: 0.0127
# Epoch 277/450
#  - 0s - loss: 0.0116 - val_loss: 0.0144
# Epoch 278/450
#  - 0s - loss: 0.0117 - val_loss: 0.0121
# Epoch 279/450
#  - 0s - loss: 0.0112 - val_loss: 0.0136
# Epoch 280/450
#  - 0s - loss: 0.0114 - val_loss: 0.0118
# Epoch 281/450
#  - 0s - loss: 0.0108 - val_loss: 0.0129
# Epoch 282/450
#  - 0s - loss: 0.0110 - val_loss: 0.0118
# Epoch 283/450
#  - 0s - loss: 0.0113 - val_loss: 0.0119
# Epoch 284/450
#  - 0s - loss: 0.0118 - val_loss: 0.0128
# Epoch 285/450
#  - 0s - loss: 0.0127 - val_loss: 0.0124
# Epoch 286/450
#  - 0s - loss: 0.0119 - val_loss: 0.0152
# Epoch 287/450
#  - 0s - loss: 0.0123 - val_loss: 0.0127
# Epoch 288/450
#  - 0s - loss: 0.0116 - val_loss: 0.0143
# Epoch 289/450
#  - 0s - loss: 0.0116 - val_loss: 0.0119
# Epoch 290/450
#  - 0s - loss: 0.0109 - val_loss: 0.0128
# Epoch 291/450
#  - 0s - loss: 0.0109 - val_loss: 0.0119
# Epoch 292/450
#  - 0s - loss: 0.0112 - val_loss: 0.0119
# Epoch 293/450
#  - 0s - loss: 0.0118 - val_loss: 0.0128
# Epoch 294/450
#  - 0s - loss: 0.0126 - val_loss: 0.0124
# Epoch 295/450
#  - 0s - loss: 0.0118 - val_loss: 0.0150
# Epoch 296/450
#  - 0s - loss: 0.0121 - val_loss: 0.0126
# Epoch 297/450
#  - 0s - loss: 0.0115 - val_loss: 0.0141
# Epoch 298/450
#  - 0s - loss: 0.0115 - val_loss: 0.0119
# Epoch 299/450
#  - 0s - loss: 0.0109 - val_loss: 0.0130
# Epoch 300/450
#  - 0s - loss: 0.0110 - val_loss: 0.0117
# Epoch 301/450
#  - 0s - loss: 0.0110 - val_loss: 0.0119
# Epoch 302/450
#  - 0s - loss: 0.0116 - val_loss: 0.0127
# Epoch 303/450
#  - 0s - loss: 0.0127 - val_loss: 0.0124
# Epoch 304/450
#  - 0s - loss: 0.0119 - val_loss: 0.0150
# Epoch 305/450
#  - 0s - loss: 0.0121 - val_loss: 0.0125
# Epoch 306/450
#  - 0s - loss: 0.0114 - val_loss: 0.0139
# Epoch 307/450
#  - 0s - loss: 0.0114 - val_loss: 0.0118
# Epoch 308/450
#  - 0s - loss: 0.0108 - val_loss: 0.0130
# Epoch 309/450
#  - 0s - loss: 0.0110 - val_loss: 0.0116
# Epoch 310/450
#  - 0s - loss: 0.0108 - val_loss: 0.0120
# Epoch 311/450
#  - 0s - loss: 0.0117 - val_loss: 0.0126
# Epoch 312/450
#  - 0s - loss: 0.0125 - val_loss: 0.0123
# Epoch 313/450
#  - 0s - loss: 0.0118 - val_loss: 0.0149
# Epoch 314/450
#  - 0s - loss: 0.0120 - val_loss: 0.0124
# Epoch 315/450
#  - 0s - loss: 0.0115 - val_loss: 0.0145
# Epoch 316/450
#  - 0s - loss: 0.0115 - val_loss: 0.0118
# Epoch 317/450
#  - 0s - loss: 0.0108 - val_loss: 0.0125
# Epoch 318/450
#  - 0s - loss: 0.0109 - val_loss: 0.0120
# Epoch 319/450
#  - 0s - loss: 0.0115 - val_loss: 0.0119
# Epoch 320/450
#  - 0s - loss: 0.0117 - val_loss: 0.0131
# Epoch 321/450
#  - 0s - loss: 0.0125 - val_loss: 0.0124
# Epoch 322/450
#  - 0s - loss: 0.0119 - val_loss: 0.0154
# Epoch 323/450
#  - 0s - loss: 0.0120 - val_loss: 0.0123
# Epoch 324/450
#  - 0s - loss: 0.0111 - val_loss: 0.0135
# Epoch 325/450
#  - 0s - loss: 0.0111 - val_loss: 0.0116
# Epoch 326/450
#  - 0s - loss: 0.0107 - val_loss: 0.0121
# Epoch 327/450
#  - 0s - loss: 0.0110 - val_loss: 0.0122
# Epoch 328/450
#  - 0s - loss: 0.0120 - val_loss: 0.0120
# Epoch 329/450
#  - 0s - loss: 0.0117 - val_loss: 0.0143
# Epoch 330/450
#  - 0s - loss: 0.0122 - val_loss: 0.0125
# Epoch 331/450
#  - 0s - loss: 0.0117 - val_loss: 0.0150
# Epoch 332/450
#  - 0s - loss: 0.0118 - val_loss: 0.0119
# Epoch 333/450
#  - 0s - loss: 0.0109 - val_loss: 0.0127
# Epoch 334/450
#  - 0s - loss: 0.0108 - val_loss: 0.0117
# Epoch 335/450
#  - 0s - loss: 0.0110 - val_loss: 0.0118
# Epoch 336/450
#  - 0s - loss: 0.0115 - val_loss: 0.0128
# Epoch 337/450
#  - 0s - loss: 0.0127 - val_loss: 0.0123
# Epoch 338/450
#  - 0s - loss: 0.0119 - val_loss: 0.0156
# Epoch 339/450
#  - 0s - loss: 0.0121 - val_loss: 0.0124
# Epoch 340/450
#  - 0s - loss: 0.0113 - val_loss: 0.0138
# Epoch 341/450
#  - 0s - loss: 0.0113 - val_loss: 0.0117
# Epoch 342/450
#  - 0s - loss: 0.0108 - val_loss: 0.0127
# Epoch 343/450
#  - 0s - loss: 0.0108 - val_loss: 0.0117
# Epoch 344/450
#  - 0s - loss: 0.0111 - val_loss: 0.0118
# Epoch 345/450
#  - 0s - loss: 0.0116 - val_loss: 0.0127
# Epoch 346/450
#  - 0s - loss: 0.0126 - val_loss: 0.0122
# Epoch 347/450
#  - 0s - loss: 0.0119 - val_loss: 0.0158
# Epoch 348/450
#  - 0s - loss: 0.0123 - val_loss: 0.0126
# Epoch 349/450
#  - 0s - loss: 0.0114 - val_loss: 0.0140
# Epoch 350/450
#  - 0s - loss: 0.0115 - val_loss: 0.0118
# Epoch 351/450
#  - 0s - loss: 0.0109 - val_loss: 0.0133
# Epoch 352/450
#  - 0s - loss: 0.0110 - val_loss: 0.0115
# Epoch 353/450
#  - 0s - loss: 0.0106 - val_loss: 0.0122
# Epoch 354/450
#  - 0s - loss: 0.0108 - val_loss: 0.0119
# Epoch 355/450
#  - 0s - loss: 0.0116 - val_loss: 0.0119
# Epoch 356/450
#  - 0s - loss: 0.0115 - val_loss: 0.0138
# Epoch 357/450
#  - 0s - loss: 0.0125 - val_loss: 0.0125
# Epoch 358/450
#  - 0s - loss: 0.0120 - val_loss: 0.0157
# Epoch 359/450
#  - 0s - loss: 0.0122 - val_loss: 0.0124
# Epoch 360/450
#  - 0s - loss: 0.0112 - val_loss: 0.0137
# Epoch 361/450
#  - 0s - loss: 0.0113 - val_loss: 0.0117
# Epoch 362/450
#  - 0s - loss: 0.0108 - val_loss: 0.0131
# Epoch 363/450
#  - 0s - loss: 0.0109 - val_loss: 0.0115
# Epoch 364/450
#  - 0s - loss: 0.0106 - val_loss: 0.0118
# Epoch 365/450
#  - 0s - loss: 0.0109 - val_loss: 0.0124
# Epoch 366/450
#  - 0s - loss: 0.0120 - val_loss: 0.0120
# Epoch 367/450
#  - 0s - loss: 0.0119 - val_loss: 0.0149
# Epoch 368/450
#  - 0s - loss: 0.0124 - val_loss: 0.0126
# Epoch 369/450
#  - 0s - loss: 0.0117 - val_loss: 0.0147
# Epoch 370/450
#  - 0s - loss: 0.0116 - val_loss: 0.0117
# Epoch 371/450
#  - 0s - loss: 0.0108 - val_loss: 0.0125
# Epoch 372/450
#  - 0s - loss: 0.0107 - val_loss: 0.0116
# Epoch 373/450
#  - 0s - loss: 0.0110 - val_loss: 0.0118
# Epoch 374/450
#  - 0s - loss: 0.0113 - val_loss: 0.0132
# Epoch 375/450
#  - 0s - loss: 0.0127 - val_loss: 0.0126
# Epoch 376/450
#  - 0s - loss: 0.0121 - val_loss: 0.0160
# Epoch 377/450
#  - 0s - loss: 0.0123 - val_loss: 0.0126
# Epoch 378/450
#  - 0s - loss: 0.0114 - val_loss: 0.0141
# Epoch 379/450
#  - 0s - loss: 0.0115 - val_loss: 0.0119
# Epoch 380/450
#  - 0s - loss: 0.0110 - val_loss: 0.0135
# Epoch 381/450
#  - 0s - loss: 0.0111 - val_loss: 0.0115
# Epoch 382/450
#  - 0s - loss: 0.0106 - val_loss: 0.0123
# Epoch 383/450
#  - 0s - loss: 0.0107 - val_loss: 0.0116
# Epoch 384/450
#  - 0s - loss: 0.0109 - val_loss: 0.0118
# Epoch 385/450
#  - 0s - loss: 0.0116 - val_loss: 0.0126
# Epoch 386/450
#  - 0s - loss: 0.0125 - val_loss: 0.0122
# Epoch 387/450
#  - 0s - loss: 0.0119 - val_loss: 0.0157
# Epoch 388/450
#  - 0s - loss: 0.0122 - val_loss: 0.0125
# Epoch 389/450
#  - 0s - loss: 0.0116 - val_loss: 0.0146
# Epoch 390/450
#  - 0s - loss: 0.0115 - val_loss: 0.0117
# Epoch 391/450
#  - 0s - loss: 0.0107 - val_loss: 0.0124
# Epoch 392/450
#  - 0s - loss: 0.0107 - val_loss: 0.0117
# Epoch 393/450
#  - 0s - loss: 0.0112 - val_loss: 0.0118
# Epoch 394/450
#  - 0s - loss: 0.0114 - val_loss: 0.0137
# Epoch 395/450
#  - 0s - loss: 0.0125 - val_loss: 0.0125
# Epoch 396/450
#  - 0s - loss: 0.0120 - val_loss: 0.0158
# Epoch 397/450
#  - 0s - loss: 0.0122 - val_loss: 0.0125
# Epoch 398/450
#  - 0s - loss: 0.0115 - val_loss: 0.0145
# Epoch 399/450
#  - 0s - loss: 0.0114 - val_loss: 0.0116
# Epoch 400/450
#  - 0s - loss: 0.0107 - val_loss: 0.0125
# Epoch 401/450
#  - 0s - loss: 0.0107 - val_loss: 0.0115
# Epoch 402/450
#  - 0s - loss: 0.0109 - val_loss: 0.0118
# Epoch 403/450
#  - 0s - loss: 0.0112 - val_loss: 0.0132
# Epoch 404/450
#  - 0s - loss: 0.0127 - val_loss: 0.0126
# Epoch 405/450
#  - 0s - loss: 0.0121 - val_loss: 0.0159
# Epoch 406/450
#  - 0s - loss: 0.0123 - val_loss: 0.0125
# Epoch 407/450
#  - 0s - loss: 0.0115 - val_loss: 0.0145
# Epoch 408/450
#  - 0s - loss: 0.0114 - val_loss: 0.0116
# Epoch 409/450
#  - 0s - loss: 0.0107 - val_loss: 0.0125
# Epoch 410/450
#  - 0s - loss: 0.0106 - val_loss: 0.0115
# Epoch 411/450
#  - 0s - loss: 0.0108 - val_loss: 0.0118
# Epoch 412/450
#  - 0s - loss: 0.0112 - val_loss: 0.0127
# Epoch 413/450
#  - 0s - loss: 0.0125 - val_loss: 0.0122
# Epoch 414/450
#  - 0s - loss: 0.0119 - val_loss: 0.0156
# Epoch 415/450
#  - 0s - loss: 0.0121 - val_loss: 0.0124
# Epoch 416/450
#  - 0s - loss: 0.0114 - val_loss: 0.0144
# Epoch 417/450
#  - 0s - loss: 0.0114 - val_loss: 0.0117
# Epoch 418/450
#  - 0s - loss: 0.0107 - val_loss: 0.0126
# Epoch 419/450
#  - 0s - loss: 0.0107 - val_loss: 0.0114
# Epoch 420/450
#  - 0s - loss: 0.0105 - val_loss: 0.0118
# Epoch 421/450
#  - 0s - loss: 0.0110 - val_loss: 0.0127
# Epoch 422/450
#  - 0s - loss: 0.0124 - val_loss: 0.0120
# Epoch 423/450
#  - 0s - loss: 0.0119 - val_loss: 0.0147
# Epoch 424/450
#  - 0s - loss: 0.0122 - val_loss: 0.0125
# Epoch 425/450
#  - 0s - loss: 0.0116 - val_loss: 0.0147
# Epoch 426/450
#  - 0s - loss: 0.0116 - val_loss: 0.0119
# Epoch 427/450
#  - 0s - loss: 0.0108 - val_loss: 0.0131
# Epoch 428/450
#  - 0s - loss: 0.0109 - val_loss: 0.0114
# Epoch 429/450
#  - 0s - loss: 0.0105 - val_loss: 0.0121
# Epoch 430/450
#  - 0s - loss: 0.0106 - val_loss: 0.0114
# Epoch 431/450
#  - 0s - loss: 0.0105 - val_loss: 0.0118
# Epoch 432/450
#  - 0s - loss: 0.0112 - val_loss: 0.0125
# Epoch 433/450
#  - 0s - loss: 0.0126 - val_loss: 0.0122
# Epoch 434/450
#  - 0s - loss: 0.0119 - val_loss: 0.0155
# Epoch 435/450
#  - 0s - loss: 0.0121 - val_loss: 0.0124
# Epoch 436/450
#  - 0s - loss: 0.0114 - val_loss: 0.0144
# Epoch 437/450
#  - 0s - loss: 0.0114 - val_loss: 0.0117
# Epoch 438/450
#  - 0s - loss: 0.0108 - val_loss: 0.0127
# Epoch 439/450
#  - 0s - loss: 0.0108 - val_loss: 0.0114
# Epoch 440/450
#  - 0s - loss: 0.0105 - val_loss: 0.0118
# Epoch 441/450
#  - 0s - loss: 0.0107 - val_loss: 0.0120
# Epoch 442/450
#  - 0s - loss: 0.0115 - val_loss: 0.0119
# Epoch 443/450
#  - 0s - loss: 0.0116 - val_loss: 0.0142
# Epoch 444/450
#  - 0s - loss: 0.0123 - val_loss: 0.0125
# Epoch 445/450
#  - 0s - loss: 0.0118 - val_loss: 0.0154
# Epoch 446/450
#  - 0s - loss: 0.0121 - val_loss: 0.0123
# Epoch 447/450
#  - 0s - loss: 0.0113 - val_loss: 0.0143
# Epoch 448/450
#  - 0s - loss: 0.0114 - val_loss: 0.0116
# Epoch 449/450
#  - 0s - loss: 0.0106 - val_loss: 0.0123
# Epoch 450/450
#  - 0s - loss: 0.0106 - val_loss: 0.0115
# rmse 5.38
